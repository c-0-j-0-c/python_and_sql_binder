# %% [markdown]
# #### Run this code for a quiz.

# %%
from jupyterquiz import display_quiz
display_quiz("./.quiz/first_lesson.json")
# Out:
# <div id="EHqRPWXpEBQl" data-shufflequestions="False"
#                data-shuffleanswers="True"
#                data-numquestions="1000000"> <style>:root {
#     --medium-slate-blue: #6f78ffff;
#     --orange-pantone: #f75c03ff;
#     --russian-violet: #392061ff;
#     --maximum-yellow-red: #ffc857ff;
#     --viridian-green: #119da4ff;
#     --incorrect-red: #c80202;
#     --correct-green: #009113;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
#     margin-bottom: 15px;
#     padding-bottom: 4px;
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
# }
#
# .QuizCode {
#     font-size: 14pt;
#     margin-top: 10px;
#     margin-left: 20px;
#     margin-right: 20px;
# }
#
# .QuizCode>pre {
#     padding: 4px;
# }
#
# .Answer {
#     margin: 10px 0;
#     display: grid;
#     grid-template-columns: auto auto;
#     grid-gap: 10px;
# }
#
# .Feedback {
#     font-size: 16pt;
#     text-align: center;
# ...

# %% [markdown]
# Here is a word search which has all the answers from your quiz in it
#
# ```
# C O N T I N U E
# B R E A K T T N
# A N D W P F R F
# E L S E H U Y A
# W N C E T I E L
# I X U E F N L S
# E R R F O V I E
# T C I N R H F N
# ```

# %%
word_search = ["CONTINUE","BREAKTTN", "ANDWPFRF","ELSEHUYA","WNCETIEL", "IXUEFNLS", "ERRFOVIE", "TCINRHFN"]
print(word_search)
# Out:
# ['CONTINUE', 'BREAKTTN', 'ANDWPFRF', 'ELSEHUYA', 'WNCETIEL', 'IXUEFNLS', 'ERRFOVIE', 'TCINRHFN']

# %% [markdown]
# #### Write some code to print out the list so it looks like above.
#
# **Hints**</br>
# * You can use `list("apple")` returns `['a','p','p','l','e']`
# * You can use the  .join method eg `"*".join(list("apple"))` to get `'a*p*p*l*e'`
#
# * To iterate over items you can use the keyword from last answer in the quiz.

# %% [markdown]
# #### Write some code to see if and appears in `"ANDWPFRF"`
# **Hints**
# * You might want to use a string method which makes words uppercase. To find it if you cannot remember do `help(str)`
# * One of the answers in the quiz might help you
# * Need to test if something is true.

# %%
row = "ANDWPFRF"
word = "and"

# %% [markdown]
# #### Write a function `left_to_right` which has arguments `word` and `word_search` to see if word `and` occurs in any row from left to right.
# **Hints**
# * a keyword you use in printing word_search is useful again

# %%
word = "and"
def left_to_right(word, word_search):

print(left_to_right(word, word_search))

# %% [markdown]
# #### Write a funcition `right_to_left` which has arguments `word` and `word_search` to see if word `and` occurs in a row from right to left.
# **Hints**
# * Remember to reverse a string you can do `"a_word"[::-1]`

# %%
def left_to_right(word, word_search):

# %% [markdown]
# ##### Remember last lesson, if you suspect it is possible for your code to raise a sort kind of error; you can catch the error and execute some code if the error errors.

# %%
fruit = ["apple"]
fruit[2]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10152/2095253564.py in <module>
#       1 fruit = ["apple"]
# ----> 2 fruit[2]
#
# IndexError: list index out of range

# %%
try:
    fruit[2]
except IndexError:
    print("AAAAAAAAAAAAAAAAAAAaH")
# Out:
# AAAAAAAAAAAAAAAAAAAaH

# %% [markdown]
# #### Write some code that handles an error if a string cannot be converted to an integer.
#
# **Hint**
# * To convert a string to an integer; use `int()`

# %%
string = "Banana09"

# %% [markdown]
# #### Print out the pattern but use string multiplication to minimise typing (You can ignore the weird indenting this cell does)
#
# **Hints**
# * remember "\n" is the new line character.
#
# ```
# *^*^*^
# ^*^*^*
# *^*^*^
# ^*^*^*
# ```

# %%
pattern = "*^"

# %% [markdown]
# #### Print out all multiples of 7 in the range 1 to 150
#
# **Hints**
# * Loop over `range(start, stop, step)` where stop is not included
# * Don't want to print on each line so use `end = " "` in print
