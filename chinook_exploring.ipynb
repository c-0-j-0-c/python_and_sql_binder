# %%
! git clone https://github.com/catherinedevlin/ipython-sql.git
! pip install ipython-sql/
# Out:
# fatal: destination path 'ipython-sql' already exists and is not an empty directory.
# Processing ./ipython-sql
#   DEPRECATION: A future pip version will change local packages to be built in-place without first copying to a temporary directory. We recommend you use --use-feature=in-tree-build to test your packages with this new behavior before it becomes the default.
#    pip 21.3 will remove support for this functionality. You can find discussion regarding this at https://github.com/pypa/pip/issues/7555.
# ...
#   Created wheel for ipython-sql: filename=ipython_sql-0.4.1-py3-none-any.whl size=20070 sha256=679dd3f5f23d406a09946416b1d0a2255d4640b533484f8daeeea5a24ccb9bf0
#   Stored in directory: /home/jovyan/.cache/pip/wheels/42/b4/f9/2115b9e4f6a51528b59571e8c61ed0fe57aec749321e4c4996
# Successfully built ipython-sql
# ...
#   Attempting uninstall: ipython-sql
#     Found existing installation: ipython-sql 0.4.1
#     Uninstalling ipython-sql-0.4.1:
# ...

# %%
# %load_ext sql
# %config SqlMagic.displaycon = False
# %config SqlMagic.feedback = False
# !wget -q -O Chinook.db https://github.com/lerocha/chinook-database/blob/master/ChinookDatabase/DataSources/Chinook_Sqlite.sqlite?raw=true
# %sql sqlite:///Chinook.db

# %%
# %%capture tablesStr
# !sqlite3 Chinook.db .table

# %%
tables = tablesStr.stdout.split()
tables.sort()
AllTables = " ".join([table for table in tables])
print(AllTables)
# Out:
# Album Artist Customer Employee Genre Invoice InvoiceLine MediaType Playlist PlaylistTrack Track

# %%
# !./getAttributes.sh Chinook.db $AllTables
# Out:
# Album Attributes
# ------------------------------------------------------
# cid  name      type           notnull  dflt_value  pk
# ---  --------  -------------  -------  ----------  --
# 0    AlbumId   INTEGER        1                    1
# 1    Title     NVARCHAR(160)  1                    0
# 2    ArtistId  INTEGER        1                    0
#
# Artist Attributes
# ------------------------------------------------------
# cid  name      type           notnull  dflt_value  pk
# ---  --------  -------------  -------  ----------  --
# 0    ArtistId  INTEGER        1                    1
# 1    Name      NVARCHAR(120)  0                    0
#
# Customer Attributes
# ------------------------------------------------------
# cid  name          type          notnull  dflt_value  pk
# ---  ------------  ------------  -------  ----------  --
# 0    CustomerId    INTEGER       1                    1
# 1    FirstName     NVARCHAR(40)  1                    0
# ...

# %%
# !sqlite3 Chinook.db .schema
# Out:
# CREATE TABLE [Album]
# (
#     [AlbumId] INTEGER  NOT NULL,
#     [Title] NVARCHAR(160)  NOT NULL,
#     [ArtistId] INTEGER  NOT NULL,
#     CONSTRAINT [PK_Album] PRIMARY KEY  ([AlbumId]),
#     FOREIGN KEY ([ArtistId]) REFERENCES [Artist] ([ArtistId])
# 		ON DELETE NO ACTION ON UPDATE NO ACTION
# );
# CREATE TABLE [Artist]
# (
#     [ArtistId] INTEGER  NOT NULL,
#     [Name] NVARCHAR(120),
#     CONSTRAINT [PK_Artist] PRIMARY KEY  ([ArtistId])
# );
# CREATE TABLE [Customer]
# (
#     [CustomerId] INTEGER  NOT NULL,
#     [FirstName] NVARCHAR(40)  NOT NULL,
#     [LastName] NVARCHAR(20)  NOT NULL,
#     [Company] NVARCHAR(80),
#     [Address] NVARCHAR(70),
#     [City] NVARCHAR(40),
#     [State] NVARCHAR(40),
#     [Country] NVARCHAR(40),
#     [PostalCode] NVARCHAR(10),
#     [Phone] NVARCHAR(24),
#     [Fax] NVARCHAR(24),
#     [Email] NVARCHAR(60)  NOT NULL,
#     [SupportRepId] INTEGER,
#     CONSTRAINT [PK_Customer] PRIMARY KEY  ([CustomerId]),
# ...

# %%
# %%bash
# sqlite3 Chinook.db
# .headers on
# .mode column
# .print "Album Attributes\n------------------------------------------------------"
# pragma table_info('Album');
# .quit
# Out:
# Album Attributes
# ------------------------------------------------------
# cid  name      type           notnull  dflt_value  pk
# ---  --------  -------------  -------  ----------  --
# 0    AlbumId   INTEGER        1                    1
# 1    Title     NVARCHAR(160)  1                    0
# 2    ArtistId  INTEGER        1                    0

# %%
# !./getAttributes.sh Chinook.db Artist
# Out:
# Artist Attributes
# ------------------------------------------------------
# cid  name      type           notnull  dflt_value  pk
# ---  --------  -------------  -------  ----------  --
# 0    ArtistId  INTEGER        1                    1
# 1    Name      NVARCHAR(120)  0                    0

# %%
# %%sql
# select * from Album
# LIMIT 10
# Out:
# [(1, 'For Those About To Rock We Salute You', 1),
#  (2, 'Balls to the Wall', 2),
#  (3, 'Restless and Wild', 2),
#  (4, 'Let There Be Rock', 1),
#  (5, 'Big Ones', 3),
#  (6, 'Jagged Little Pill', 4),
#  (7, 'Facelift', 5),
#  (8, 'Warner 25 Anos', 6),
#  (9, 'Plays Metallica By Four Cellos', 7),
#  (10, 'Audioslave', 8)]

# %%
print(_)
# Out:
# +---------+---------------------------------------+----------+
# | AlbumId |                 Title                 | ArtistId |
# +---------+---------------------------------------+----------+
# |    1    | For Those About To Rock We Salute You |    1     |
# |    2    |           Balls to the Wall           |    2     |
# |    3    |           Restless and Wild           |    2     |
# |    4    |           Let There Be Rock           |    1     |
# |    5    |                Big Ones               |    3     |
# |    6    |           Jagged Little Pill          |    4     |
# |    7    |                Facelift               |    5     |
# |    8    |             Warner 25 Anos            |    6     |
# |    9    |     Plays Metallica By Four Cellos    |    7     |
# |    10   |               Audioslave              |    8     |
# +---------+---------------------------------------+----------+

# %%
# %%bash
# sqlite3 Chinook.db
# SELECT * FROM Album
# LIMIT 10;
# .quit
# Out:
# 1|For Those About To Rock We Salute You|1
# 2|Balls to the Wall|2
# 3|Restless and Wild|2
# 4|Let There Be Rock|1
# 5|Big Ones|3
# 6|Jagged Little Pill|4
# 7|Facelift|5
# 8|Warner 25 Anos|6
# 9|Plays Metallica By Four Cellos|7
# 10|Audioslave|8
